# %% [markdown]
# <a href="https://colab.research.google.com/github/oscar-oliva/ejemplo_clase_borrar/blob/main/Copia/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es un título
# ##Este es un título más pequeño
# Este es un título

# %% [markdown]
# ![udep_gobierno-scaled.jpg](data:image/jpeg;base64,...)

# %%
2.5/2
# Out:
# 1.25

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/LogoUDEP.svg/1200px-LogoUDEP.svg.png" alt="HTML5 Icon">
